# %%
import os
from pathlib import Path

home = os.path.join(os.path.expanduser("~"), "buni")
pseudo_labels_dir = os.path.join(home, "output-data", "av2", "test_bbox_script")

av2_path = Path(os.path.join(home, "dataset", "av2", "train"))

# %%
from av2.datasets.sensor.av2_sensor_dataloader import AV2SensorDataLoader

dataset_api = AV2SensorDataLoader(data_dir=av2_path, labels_dir=av2_path)

scene_id = "ff52c01e-3d7b-32b1-b6a1-bcff3459ccdd"

frame_id = "315968335160099000"

# %%
dataset_api.get_labels_at_lidar_timestamp(scene_id, int(frame_id)).vertices_m
# Out:
# array([[[ 1.10339699e+02, -1.40992787e+02,  3.83831634e+00],
#         [ 1.10995580e+02, -1.41532069e+02,  3.83831634e+00],
#         [ 1.10995580e+02, -1.41532069e+02,  1.88116016e+00],
#         ...,
#         [ 1.09870145e+02, -1.42900836e+02,  3.83831634e+00],
#         [ 1.09870145e+02, -1.42900836e+02,  1.88116016e+00],
#         [ 1.09214264e+02, -1.42361554e+02,  1.88116016e+00]],
#
#        [[ 9.52881271e+01, -1.95982949e+01,  1.72838171e+00],
#         [ 9.58104142e+01, -1.86449485e+01,  1.72838171e+00],
#         [ 9.58104142e+01, -1.86449485e+01,  1.20092153e-02],
#         ...,
#         [ 9.67845415e+01, -1.91786203e+01,  1.72838171e+00],
#         [ 9.67845415e+01, -1.91786203e+01,  1.20092153e-02],
#         [ 9.62622543e+01, -2.01319667e+01,  1.20092153e-02]],
#
#        [[ 9.51066494e+01, -1.96410595e+01,  1.51440991e+00],
#         [ 9.55491616e+01, -1.88035658e+01,  1.51440991e+00],
#         [ 9.55491616e+01, -1.88035658e+01,  1.44099099e-02],
#         ...,
# ...
